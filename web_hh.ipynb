# %% [markdown]
# # Анализ вакансий hh на дата-аналитика

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  sklearn.ensemble import IsolationForest
import warnings

import requests
from pprint import pprint
from bs4 import BeautifulSoup
import re

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Создание датафрейма, парсинг информации

# %%
# подготовим пустой датафрейм с необходимыми полями
columns = 'id', 'name', 'insider_interview', 'response_letter_required', 'salary', 'address', 'allow_messages',\
     'experience', 'schedule', 'employment', 'department', 'contacts', 'description', 'key_skills', 'professional_roles', 'employer',\
     'published_at', 'created_at', 'apply_alternate_url', 'has_test', 'test', 'alternate_url',\
     'accept_temporary', 'languages'
df = pd.DataFrame(columns = columns)
df
# Out:
# Empty DataFrame
# Columns: [id, relations, name, insider_interview, response_letter_required, salary, type, address, allow_messages, experience, schedule, employment, department, contacts, description, key_skills, professional_roles, employer, published_at, created_at, apply_alternate_url, has_test, test, alternate_url, working_days, working_time_intervals, working_time_modes, accept_temporary, languages]
# Index: []
#
# [0 rows x 29 columns]

# %%
# общая страница с вакансиями
url = 'https://api.hh.ru/vacancies?search_field=name&search_field=company_name&search_field=description&text=data+scientist'
response = requests.get(url)
page_json = response.json()

# количество страниц
pages = page_json['pages']
# Out:
# 18

# %%
#цикл по страницам с вакансиями
for page in range(pages):
    par = {'page':page}
    response = requests.get(url, params=par)
    page_json = response.json()

    # перебор всех вакансий на странице
    for item in page_json['items']:
        url_vacancy = item['url']   # переходим на страницу вакансии
        response = requests.get(url_vacancy)
        vacancy_json = response.json()
        dict_vacancy = {}

        for column in columns:
            dict_vacancy[column] = vacancy_json[column]

        df = df.append(dict_vacancy, ignore_index=True)

# %%
# сохраним в формат csv

df.to_csv('data/data_vacancy.csv', sep=';')

# %% [markdown]
# ## Обработка данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        361 non-null    object
#  1   relations                 361 non-null    object
#  2   name                      361 non-null    object
#  3   insider_interview         1 non-null      object
#  4   response_letter_required  361 non-null    object
#  5   salary                    63 non-null     object
#  6   type                      361 non-null    object
#  7   address                   147 non-null    object
#  8   allow_messages            361 non-null    object
#  9   experience                361 non-null    object
#  10  schedule                  361 non-null    object
#  11  employment                361 non-null    object
#  12  department                123 non-null    object
#  13  contacts                  0 non-null      object
#  14  description               361 non-null    object
#  15  key_skills                361 non-null    object
#  16  professional_roles        361 non-null    object
#  17  employer                  361 non-null    object
#  18  published_at              361 non-null    object
#  19  created_at                361 non-null    object
#  20  apply_alternate_url       361 non-null    object
#  21  has_test                  361 non-null    object
#  22  test                      8 non-null      object
#  23  alternate_url             361 non-null    object
#  24  working_days              361 non-null    object
#  25  working_time_intervals    361 non-null    object
#  26  working_time_modes        361 non-null    object
#  27  accept_temporary          361 non-null    object
#  28  languages                 361 non-null    object
#  29  salary_min                361 non-null    int64
#  30  salary_max                361 non-null    int64
#  31  salary_currency           361 non-null    object
# dtypes: int64(2), object(30)
# memory usage: 90.4+ KB

# %% [markdown]
# #### 1. Обработка признака salary

# %%
def get_salary(text):

    if not text :
        return [0,0,'']

    dict_text = dict(text)
    salary_min = dict_text['from']
    salary_max = dict_text['to']
    salary_currency = dict_text['currency']
    print(salary_min)
    if salary_min is None:
        salary_min = salary_max

    if salary_max is None:
        salary_max = salary_min

    return [salary_min, salary_max, salary_currency]

# %%
df['salary_min'] = df['salary'].apply(lambda x: get_salary(x)[0])
df['salary_max'] = df['salary'].apply(lambda x: get_salary(x)[1])
df['salary_currency'] = df['salary'].apply(lambda x: get_salary(x)[2])
# Out:
# 150000
# 5000
# 60000
# None
# 40000
# 200000
# 150000
# 250000
# 400000
# None
# 150000
# 100000
# 5000
# None
# 40000
# 60000
# 200000
# 150000
# 250000
# 400000
# None
# 200000
# None
# 300000
# None
# 100000
# 70000
# 350000
# 100000
# 50000
# 350000
# 3000
# 225000
# 3000
# None
# None
# 3000
# 120000
# 200000
# 150000
# None
# 5200
# 200000
# 3500
# 3500
# 120000
# 3500
# 150000
# 40000
# None
# 120000
# 400
# 7500
# 55000
# 45000
# None
# 250000
# 20000
# 200000
# None
# 3500
# 200000
# 200000
# 150000
# 5000
# 60000
# None
# 40000
# 200000
# 150000
# 250000
# 400000
# None
# 150000
# 100000
# 5000
# None
# 40000
# 60000
# 200000
# 150000
# 250000
# 400000
# None
# 200000
# None
# 300000
# None
# 100000
# 70000
# 350000
# 100000
# 50000
# 350000
# 3000
# 225000
# 3000
# None
# None
# 3000
# 120000
# 200000
# 150000
# None
# 5200
# 200000
# 3500
# 3500
# 120000
# 3500
# 150000
# 40000
# None
# 120000
# 400
# 7500
# 55000
# 45000
# None
# 250000
# 20000
# 200000
# None
# 3500
# 200000
# 200000
# 150000
# 5000
# 60000
# None
# 40000
# 200000
# 150000
# 250000
# 400000
# None
# 150000
# 100000
# 5000
# None
# 40000
# 60000
# 200000
# 150000
# 250000
# 400000
# None
# 200000
# None
# 300000
# None
# 100000
# 70000
# 350000
# 100000
# 50000
# 350000
# 3000
# 225000
# 3000
# None
# None
# 3000
# 120000
# 200000
# 150000
# None
# 5200
# 200000
# 3500
# 3500
# 120000
# 3500
# 150000
# 40000
# None
# 120000
# 400
# 7500
# 55000
# 45000
# None
# 250000
# 20000
# 200000
# None
# 3500
# 200000
# 200000

# %%
df.drop('salary', axis = 1, inplace=True)

# %% [markdown]
# #### 2. Обработка признака address

# %%
def get_address(text):

    if not text :
        return ['','','','','']

    dict_text = dict(text)
    city = dict_text['city']
    street = dict_text['street']
    lat = dict_text['lat']
    lng = dict_text['lng']
    if dict_text['metro'] and dict_text['metro']['station_name']:
        metro = dict_text['metro']['station_name']
    else:
        metro=''

    return [city, street, lat, lng, metro]

# %%
df['city'] = df['address'].apply(lambda x: get_address(x)[0])
df['street'] = df['address'].apply(lambda x: get_address(x)[1])
df['lat'] = df['address'].apply(lambda x: get_address(x)[2])
df['lng'] = df['address'].apply(lambda x: get_address(x)[3])
df['metro'] = df['address'].apply(lambda x: get_address(x)[4])

# %%
df = df.drop('address', axis = 1)

# %% [markdown]
# #### 3. Обработка признака experience

# %%
df['experience'] = df['experience'].apply(lambda x:dict(x)['name'] if x else '')

# %% [markdown]
# #### 3. Обработка признака schedule

# %%
df['schedule'] = df['schedule'].apply(lambda x:dict(x)['name'] if x else '')

# %% [markdown]
# #### 4. Обработка признака employment

# %%
df['employment'] = df['employment'].apply(lambda x:dict(x)['name'] if x else '')

# %% [markdown]
# #### 5. Обработка признака department

# %%
df['department'] = df['department'].apply(lambda x:dict(x)['name'] if x else '')

# %% [markdown]
# #### 6. Обработка признака professional_roles

# %%
df['professional_roles'] = df['professional_roles'].apply(lambda x:dict(x[0])['name'] if x else '')

# %% [markdown]
# #### 7. Обработка признака employer

# %%
df['employer_name'] = df['employer'].apply(lambda x:dict(x)['name'] if x else '')
df['employer_url'] = df['employer'].apply(lambda x:dict(x)['alternate_url'] if x else '')
df.drop('employer', axis=1, inplace=True)

# %% [markdown]
# #### 8. Обработка признака description

# %%
df['description'] = df['description'].apply(lambda x:(re.sub(r'\<[^>]*\>', '', x)) if x else '')

# %%
df['description']
# Out:
# 0      Обязанности:  Работа в команде по созданию мод...
# 1      Наша компания «СтандартПроект» является лидеро...
# 2      FUNCORP, разработчик развлекательных UGC-прило...
# 3      Программист Python/Data Scientist (junior / mi...
# 4      Мы - бизнес-юнит &quot;Unity Fintech&quot;, ко...
#                              ...
# 356    Обязанности:   Запуск автокредитования с нуля ...
# 357    The DataOps team is responsible for the buildi...
# 358    Hi there! We are Semrush, a global IT company ...
# 359    Команда AI Hub Group - это комьюнити талантлив...
# 360    Мы в Rubbles занимаемся созданием Data Science...
# Name: description, Length: 361, dtype: object

# %%
df.drop(['relations', 'type'], axis=1, inplace=True)

# %%
df.head()
# Out:
#          id                                               name  \
# 0  69724262                                     Data scientist
# 1  70471850                   Аналитик данных / Data scientist
# 2  67716744                       Senior Data Scientist (Yepp)
# 3  69383038  Программист Python/Data Scientist (junior / mi...
# 4  70373083                                     Data Scientist
#
#   insider_interview response_letter_required allow_messages  \
# 0              None                    False           True
# 1              None                    False           True
# 2              None                    False          False
# 3              None                    False           True
# 4              None                    False           True
#
#            experience          schedule        employment department contacts  \
# 0       От 3 до 6 лет  Удаленная работа  Полная занятость                None
# 1  От 1 года до 3 лет       Полный день  Полная занятость                None
# 2       От 3 до 6 лет       Полный день  Полная занятость                None
# 3           Нет опыта       Полный день  Полная занятость                None
# 4       От 3 до 6 лет  Удаленная работа  Полная занятость                None
#
#    ... salary_min salary_max salary_currency    city                street  \
# 0  ...     150000     200000             RUR  Москва       Походный проезд
# 1  ...          0          0                  Москва  улица Станиславского
# 2  ...       5000       8500             EUR
# 3  ...      60000     100000             RUR
# 4  ...     300000     300000             RUR
#
#          lat        lng metro             employer_name  \
# 0  55.838091  37.417167                           Астор
# 1  55.745716  37.663539                  СтандартПроект
# 2                                               FUNCORP
# 3                                               Апэрбот
# 4                              Кадровое агентство Юнити
#
#                      employer_url
# 0      https://hh.ru/employer/606
# 1  https://hh.ru/employer/2942396
# 2  https://hh.ru/employer/1212374
# 3  https://hh.ru/employer/4602050
# 4      https://hh.ru/employer/985
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        361 non-null    object
#  1   relations                 361 non-null    object
#  2   name                      361 non-null    object
#  3   insider_interview         1 non-null      object
#  4   response_letter_required  361 non-null    object
#  5   type                      361 non-null    object
#  6   allow_messages            361 non-null    object
#  7   experience                361 non-null    object
#  8   schedule                  361 non-null    object
#  9   employment                361 non-null    object
#  10  department                361 non-null    object
#  11  contacts                  0 non-null      object
#  12  description               361 non-null    object
#  13  key_skills                361 non-null    object
#  14  professional_roles        361 non-null    object
#  15  published_at              361 non-null    object
#  16  created_at                361 non-null    object
#  17  apply_alternate_url       361 non-null    object
#  18  has_test                  361 non-null    object
#  19  test                      8 non-null      object
#  20  alternate_url             361 non-null    object
#  21  working_days              361 non-null    object
#  22  working_time_intervals    361 non-null    object
#  23  working_time_modes        361 non-null    object
#  24  accept_temporary          361 non-null    object
#  25  languages                 361 non-null    object
#  26  salary_min                361 non-null    int64
#  27  salary_max                361 non-null    int64
#  28  salary_currency           361 non-null    object
#  29  city                      352 non-null    object
#  30  street                    344 non-null    object
#  31  lat                       355 non-null    object
#  32  lng                       355 non-null    object
#  33  metro                     361 non-null    object
#  34  employer_name             361 non-null    object
#  35  employer_url              361 non-null    object
# dtypes: int64(2), object(34)
# memory usage: 101.7+ KB

# %% [markdown]
# ## EDA

# %%
df[(df['salary_min']!=0) & (df['salary_currency']=='RUR')][['name', 'alternate_url', 'salary_min', 'salary_max', 'city']].sort_values('salary_min')
# Out:
#                                                   name  \
# 358                           QA Engineer (Amber Team)
# 346                 French speaking recruitment intern
# 5           Разработчик / программист / Data scientist
# 25          Разработчик / программист / Data scientist
# 293  Проджект-менеджер / Системный-аналитик в ИТ-пр...
# 317                           Специалист по системе 1С
# 139                                     Data scientist
# 314  Менеджер по продажам курсов в сфере IT и Digit...
# 3    Программист Python/Data Scientist (junior / mi...
# 26   Программист Python/Data Scientist (junior / mi...
# 103          Data Scientist (Computer Vision) / Junior
# 21   Junior HFT Quant Trader / Data Scientist Orion...
# 136          Data Scientist (Computer Vision) / Middle
# 67           Старший математик \ Senior Data scientist
# 16                                      Data Scientist
# 37                                      Data Scientist
# 305          Аналитик по динамическому ценообразованию
# 265                                        Программист
# 177                    Data scientist / ML разработчик
# 166                  Data Scientist (Удаленная работа)
# 195  Middle Data Scientist / Middle Machine Learnin...
# 0                                       Data scientist
# 279                           Data Scientist (NLP, СV)
# 33                                            Аналитик
# 20                                      Data scientist
# 11                                            Аналитик
# 164                          Middle data scientist NLP
# 187                       Middle/Senior Data Scientist
# 349                        Node.js developer (Middle+)
# 238                       Middle/Senior Data Scientist
# 360            Java/Kotlin-разработчик (Middle/Senior)
# 27   Data scientist (middle+) / Руководитель отдела...
# 359  Ведущий менеджер по продажам / Business Develo...
# 47            Middle+ Data scientist / ML разработчик.
# 7    Data scientist (middle+) / Руководитель отдела...
# 150                   Data scientist (computer vision)
# 34                               Middle Data Scientist
# 12                               Middle Data Scientist
# 328                              Senior .Net developer
# 65                               Senior Data Scientist
# 63                               Senior Data Scientist
# 205  Big Data Engineer / Data Scientist / Machine L...
# 4                                       Data Scientist
# 24                                      Data Scientist
# 147            Senior Data Scientist в b2c направление
# 129                    Data Scientist (команда Поиска)
# 15                            Team lead Data Scientist
# 35                            Team lead Data Scientist
# 351                     Data Engineer (middle+/senior)
